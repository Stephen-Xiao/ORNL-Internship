# %%
# !pip install -e ./alchemy-main
# Out:
# Obtaining file:///C:/Users/5yx/OneDrive%20-%20Oak%20Ridge%20National%20Laboratory/alchemy-main
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: torch>=1.13 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from alchemy==0.1.0) (2.7.1)
# Requirement already satisfied: gpytorch>=1.8 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from alchemy==0.1.0) (1.14)
# Requirement already satisfied: botorch>=0.7 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from alchemy==0.1.0) (0.14.0)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from alchemy==0.1.0) (1.5.1)
# Requirement already satisfied: neurobayes>=0.0.1 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from alchemy==0.1.0) (0.0.14)
# Requirement already satisfied: pandas>=1.1 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from alchemy==0.1.0) (2.2.2)
# Requirement already satisfied: matplotlib>=3.0 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from alchemy==0.1.0) (3.9.2)
# Requirement already satisfied: typing_extensions in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from botorch>=0.7->alchemy==0.1.0) (4.11.0)
# Requirement already satisfied: pyre_extensions in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from botorch>=0.7->alchemy==0.1.0) (0.0.32)
# Requirement already satisfied: linear_operator==0.6 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from botorch>=0.7->alchemy==0.1.0) (0.6)
# Requirement already satisfied: pyro-ppl>=1.8.4 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from botorch>=0.7->alchemy==0.1.0) (1.9.1)
# Requirement already satisfied: scipy in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from botorch>=0.7->alchemy==0.1.0) (1.13.1)
# Requirement already satisfied: multipledispatch in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from botorch>=0.7->alchemy==0.1.0) (0.6.0)
# Requirement already satisfied: threadpoolctl in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from botorch>=0.7->alchemy==0.1.0) (3.5.0)
# Requirement already satisfied: jaxtyping in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from gpytorch>=1.8->alchemy==0.1.0) (0.3.2)
# Requirement already satisfied: mpmath<=1.3,>=0.19 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from gpytorch>=1.8->alchemy==0.1.0) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.0->alchemy==0.1.0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.0->alchemy==0.1.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.0->alchemy==0.1.0) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.0->alchemy==0.1.0) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.0->alchemy==0.1.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.0->alchemy==0.1.0) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.0->alchemy==0.1.0) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.0->alchemy==0.1.0) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.0->alchemy==0.1.0) (2.9.0.post0)
# Requirement already satisfied: jax>=0.4.0 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from neurobayes>=0.0.1->alchemy==0.1.0) (0.6.2)
# Requirement already satisfied: jaxlib>=0.4.0 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from neurobayes>=0.0.1->alchemy==0.1.0) (0.6.2)
# Requirement already satisfied: numpyro>=0.13.0 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from neurobayes>=0.0.1->alchemy==0.1.0) (0.18.0)
# Requirement already satisfied: flax>=0.8.4 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from neurobayes>=0.0.1->alchemy==0.1.0) (0.10.6)
# Requirement already satisfied: pytz>=2020.1 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from pandas>=1.1->alchemy==0.1.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from pandas>=1.1->alchemy==0.1.0) (2023.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from scikit-learn>=1.0->alchemy==0.1.0) (1.4.2)
# Requirement already satisfied: filelock in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from torch>=1.13->alchemy==0.1.0) (3.13.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from torch>=1.13->alchemy==0.1.0) (1.14.0)
# Requirement already satisfied: networkx in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from torch>=1.13->alchemy==0.1.0) (3.3)
# Requirement already satisfied: jinja2 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from torch>=1.13->alchemy==0.1.0) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from torch>=1.13->alchemy==0.1.0) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from torch>=1.13->alchemy==0.1.0) (75.1.0)
# Requirement already satisfied: msgpack in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from flax>=0.8.4->neurobayes>=0.0.1->alchemy==0.1.0) (1.0.3)
# Requirement already satisfied: optax in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from flax>=0.8.4->neurobayes>=0.0.1->alchemy==0.1.0) (0.2.5)
# Requirement already satisfied: orbax-checkpoint in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from flax>=0.8.4->neurobayes>=0.0.1->alchemy==0.1.0) (0.11.16)
# Requirement already satisfied: tensorstore in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from flax>=0.8.4->neurobayes>=0.0.1->alchemy==0.1.0) (0.1.75)
# Requirement already satisfied: rich>=11.1 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from flax>=0.8.4->neurobayes>=0.0.1->alchemy==0.1.0) (13.7.1)
# Requirement already satisfied: PyYAML>=5.4.1 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from flax>=0.8.4->neurobayes>=0.0.1->alchemy==0.1.0) (6.0.1)
# Requirement already satisfied: treescope>=0.1.7 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from flax>=0.8.4->neurobayes>=0.0.1->alchemy==0.1.0) (0.1.9)
# Requirement already satisfied: ml_dtypes>=0.5.0 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from jax>=0.4.0->neurobayes>=0.0.1->alchemy==0.1.0) (0.5.1)
# Requirement already satisfied: opt_einsum in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from jax>=0.4.0->neurobayes>=0.0.1->alchemy==0.1.0) (3.4.0)
# Requirement already satisfied: tqdm in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from numpyro>=0.13.0->neurobayes>=0.0.1->alchemy==0.1.0) (4.66.5)
# Requirement already satisfied: pyro-api>=0.1.1 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from pyro-ppl>=1.8.4->botorch>=0.7->alchemy==0.1.0) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0->alchemy==0.1.0) (1.16.0)
# Requirement already satisfied: wadler-lindig>=0.1.3 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from jaxtyping->gpytorch>=1.8->alchemy==0.1.0) (0.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from jinja2->torch>=1.13->alchemy==0.1.0) (2.1.3)
# Requirement already satisfied: typing-inspect in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from pyre_extensions->botorch>=0.7->alchemy==0.1.0) (0.9.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from rich>=11.1->flax>=0.8.4->neurobayes>=0.0.1->alchemy==0.1.0) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from rich>=11.1->flax>=0.8.4->neurobayes>=0.0.1->alchemy==0.1.0) (2.15.1)
# Requirement already satisfied: colorama in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from tqdm->numpyro>=0.13.0->neurobayes>=0.0.1->alchemy==0.1.0) (0.4.6)
# Requirement already satisfied: absl-py>=0.7.1 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from optax->flax>=0.8.4->neurobayes>=0.0.1->alchemy==0.1.0) (2.3.0)
# Requirement already satisfied: chex>=0.1.87 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from optax->flax>=0.8.4->neurobayes>=0.0.1->alchemy==0.1.0) (0.1.89)
# Requirement already satisfied: etils[epath,epy] in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from orbax-checkpoint->flax>=0.8.4->neurobayes>=0.0.1->alchemy==0.1.0) (1.12.2)
# Requirement already satisfied: nest_asyncio in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from orbax-checkpoint->flax>=0.8.4->neurobayes>=0.0.1->alchemy==0.1.0) (1.6.0)
# Requirement already satisfied: protobuf in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from orbax-checkpoint->flax>=0.8.4->neurobayes>=0.0.1->alchemy==0.1.0) (4.25.3)
# Requirement already satisfied: humanize in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from orbax-checkpoint->flax>=0.8.4->neurobayes>=0.0.1->alchemy==0.1.0) (4.12.3)
# Requirement already satisfied: simplejson>=3.16.0 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from orbax-checkpoint->flax>=0.8.4->neurobayes>=0.0.1->alchemy==0.1.0) (3.20.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from typing-inspect->pyre_extensions->botorch>=0.7->alchemy==0.1.0) (1.0.0)
# Requirement already satisfied: toolz>=0.9.0 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from chex>=0.1.87->optax->flax>=0.8.4->neurobayes>=0.0.1->alchemy==0.1.0) (0.12.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.8.4->neurobayes>=0.0.1->alchemy==0.1.0) (0.1.0)
# Requirement already satisfied: importlib_resources in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.8.4->neurobayes>=0.0.1->alchemy==0.1.0) (6.5.2)
# Requirement already satisfied: zipp in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.8.4->neurobayes>=0.0.1->alchemy==0.1.0) (3.17.0)
# Building wheels for collected packages: alchemy
#   Building editable for alchemy (pyproject.toml): started
#   Building editable for alchemy (pyproject.toml): finished with status 'done'
#   Created wheel for alchemy: filename=alchemy-0.1.0-0.editable-py3-none-any.whl size=3231 sha256=cacd3036c97adb4365979a7ebd49eaae026e165f5f4ff7f1018c46dccef71055
#   Stored in directory: C:\Users\5yx\AppData\Local\Temp\pip-ephem-wheel-cache-u48wyjgf\wheels\3a\cf\8a\891c085432d441278afd0be442dd3d66371dff60f33dabd6e2
# Successfully built alchemy
# Installing collected packages: alchemy
#   Attempting uninstall: alchemy
#     Found existing installation: alchemy 0.1.0
#     Uninstalling alchemy-0.1.0:
#       Successfully uninstalled alchemy-0.1.0
# Successfully installed alchemy-0.1.0

# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (2.7.1)
# Requirement already satisfied: filelock in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\5yx\appdata\local\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)

# %%
from skimage.color import lab2rgb

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.quasirandom import SobolEngine
from color_picker_optimization.metrics import calculate_error, rgb2cmyk
from color_picker_optimization.plate_image_simulation import simulate_mixing, simulate_plate_image
from alchemy import step_surrogate

 
# === User Configurable Parameters === # change here until ENd User COnfig
lab_targets_path = "uniform_lab_from_rgb.npy"  # path to your Lab-space targets
save_filename    = "all_results.npz"           # output file
 
total_vol        = 275     # µL per well
max_wells        = 96  # total number of wells to sample per target
batch_size       = 4       # number of samples per batch # change
  
sobol_seed       = 42      # seed for reproducible Sobol initial batch
sobol_scramble   = True    # whether to scramble Sobol sequence
 
# Surrogate & acquisition settings
surrogate = { #change
    "name": "rf",
    "fit_kwargs": {}
}
acquisition = {
    "name": "UCB",
    "kwargs": {
        "q": batch_size,
        "beta": 0.1  # or some other float like 0.5, 1.0, etc.
    },
    "discrete": True
}

# Candidate grid resolution (per dimension)
num_points = 20  # how many grid points along each axis
 
# === End User Configs ===
 
def lab_to_cmyk(lab: np.ndarray) -> np.ndarray:
    """Convert a single Lab color → CMYK (4,)"""
    rgb01     = lab2rgb(lab.reshape(1,1,3))
    rgb_uint8 = (rgb01 * 255).astype(np.uint8)
    cmyk      = rgb2cmyk(rgb_uint8)
    return cmyk[0,0]
 
# 1) Load & convert targets
lab_targets  = np.load(lab_targets_path)                  # shape (N,3)
cmyk_targets = np.array([lab_to_cmyk(l) for l in lab_targets])
 
# 2) Prepare Sobol for initial batch
sobol = SobolEngine(dimension=4, scramble=sobol_scramble, seed=sobol_seed)
 
# 3) Prepare bounds & X_test grid in µL
bounds_frac = torch.tensor([[0.,0.,0.,0.],[1.,1.,1.,1.]])
bounds      = bounds_frac * total_vol  # [[0,0,0,0],[total_vol,...]]
 
vs = [
    torch.linspace(bounds[0,i], bounds[1,i], steps=num_points)
    for i in range(4)
]
C, M, Y, K = torch.meshgrid(*vs, indexing="ij")
X_all = torch.stack([C.reshape(-1), M.reshape(-1), Y.reshape(-1), K.reshape(-1)], dim=1)
mask   = (X_all.sum(dim=1).round() == float(total_vol))
X_test = X_all[mask]  # candidate set in µL
 
print(f"Total grid points before mask: {X_all.shape[0]}")
print(f"Grid points on simplex:         {X_test.shape[0]}")
 
all_results = []
 
# 4) Active learning loop
for idx, tgt in enumerate(cmyk_targets):
    print(f"\n=== Target #{idx} ===")
    X_vols       = []
    Y_errs       = []
    best_history = []
    best_dE      = np.inf
    taken        = 0
 
    # Initial Sobol batch
    sobol_pts = sobol.draw(batch_size).numpy()                          # fractions
    mixtures  = sobol_pts / sobol_pts.sum(axis=1, keepdims=True)
    vols      = (mixtures * total_vol).tolist()                        # µL
    obs       = simulate_mixing(vols)
    dEs       = calculate_error(obs, tgt)
 
    X_vols.extend(vols)
    Y_errs.extend([float(d) for d in dEs])
    best_dE = float(np.min(dEs))
    best_history.append(best_dE)
    taken = batch_size
 
    print(f"Init vols: {vols}")
    print(f"Init ΔE:   {dEs}, best: {best_dE}")
 
    # Main batches
    while taken < max_wells:
        bs = min(batch_size, max_wells - taken)
 
        X_t = torch.tensor(X_vols, dtype=torch.float32)
        Y_t = torch.tensor(Y_errs, dtype=torch.float32)
        print(f"\nTaken {taken}/{max_wells} → X_t.shape={X_t.shape}, Y_t.shape={Y_t.shape}")
 
        cand, mean, var, acq_vals = step_surrogate(
            X=X_t,
            Y=Y_t,
            X_test=X_test,
            bounds=bounds,
            surrogate=surrogate,
            acquisition=acquisition,
            return_acq_vals=False,
            maximize=False
        )
        proposals = cand.detach().cpu().numpy()  # µL
 
        print(f"Proposed vols:\n{proposals}")
 
        vols       = proposals.tolist()
        obs_colors = simulate_mixing(vols)
        dEs        = calculate_error(obs_colors, tgt)
 
        X_vols.extend(vols)
        Y_errs.extend([float(d) for d in dEs])
        print(f"Observed ΔE: {dEs}")
 
        best_dE = min(best_dE, float(np.min(dEs)))
        best_history.append(best_dE)
        print(f"Running best ΔE: {best_dE}")
 
        taken += bs
 
        # show updated plate image
        img = simulate_plate_image(X_vols)  # show latest batch
        plt.imshow(img)
        plt.axis('off')
        plt.title(f"Target #{idx} – after {taken} wells")
        plt.show()
 
    X_arr    = np.vstack(X_vols)
    Y_arr    = np.array(Y_errs)
    best_arr = np.array(best_history)
    all_results.append((X_arr, Y_arr, best_arr))
 
    print(f"Done target #{idx}: X_arr={X_arr.shape}, Y_arr={Y_arr.shape}, best_arr={best_arr.shape}")
 
# 5) Save results
Xs    = np.stack([res[0] for res in all_results], axis=0)  # (n_targets, max_wells, 4)
Ys    = np.stack([res[1] for res in all_results], axis=0)  # (n_targets, max_wells)
Bests = np.stack([res[2] for res in all_results], axis=0)  # (n_targets, n_batches)
 
np.savez(
    save_filename,
    Xs=Xs,
    Ys=Ys,
    bests=Bests,
    max_wells=max_wells,
    batch_size=batch_size
)
 
print(f"\nSaved all_results to {save_filename}")
# Out:
# Total grid points before mask: 160000
# Grid points on simplex:         1540
#
# === Target #0 ===
# Init vols: [[117.01456451416016, 12.24283218383789, 96.54058074951172, 49.202022552490234], [62.86850357055664, 116.38597869873047, 10.175382614135742, 85.57014465332031], [41.658390045166016, 66.868896484375, 133.2569580078125, 33.21575164794922], [76.89578247070312, 61.380393981933594, 47.094573974609375, 89.62925720214844]]
# Init ΔE:   [20.95204265346488, 99.76994503045887, 56.5836279788891, 63.32455955297705], best: 20.95204265346488
#
# Taken 4/96 → X_t.shape=torch.Size([4, 4]), Y_t.shape=torch.Size([4])
# Proposed vols:
# [[101.31579   28.947369 130.26315   14.473684]
#  [101.31579   28.947369 101.31579   43.42105 ]
#  [130.26315   28.947369 101.31579   14.473684]
#  [202.63158    0.         0.        72.36842 ]]
# Observed ΔE: [27.899471227973486, 27.589755340095298, 15.810664507613568, 35.48609854297217]
# Running best ΔE: 15.810664507613568
# Taken 8/96 → X_t.shape=torch.Size([8, 4]), Y_t.shape=torch.Size([8])
# Proposed vols:
# [[ 28.947369 101.31579   57.894737  86.8421  ]
#  [ 28.947369  72.36842   57.894737 115.789474]
#  [144.73685   28.947369 101.31579    0.      ]
#  [ 14.473684  14.473684 217.10526   28.947369]]
# Observed ΔE: [85.73440073360628, 75.34782025012355, 10.838434426989314, 69.08995549888725]
# Running best ΔE: 10.838434426989314
# Taken 12/96 → X_t.shape=torch.Size([12, 4]), Y_t.shape=torch.Size([12])
# Proposed vols:
# [[ 72.36842  101.31579   28.947369  72.36842 ]
#  [ 28.947369   0.       246.05263    0.      ]
#  [ 86.8421   159.21053    0.        28.947369]
#  [ 57.894737   0.        43.42105  173.6842  ]]
# Observed ΔE: [86.8395804207084, 77.3504161686699, 130.6143155202463, 64.70485773085709]
# Running best ΔE: 10.838434426989314
# Taken 16/96 → X_t.shape=torch.Size([16, 4]), Y_t.shape=torch.Size([16])
# Proposed vols:
# [[101.31579  115.789474  57.894737   0.      ]
#  [159.21053   43.42105   72.36842    0.      ]
#  [144.73685   28.947369 101.31579    0.      ]
#  [ 28.947369  86.8421   130.26315   28.947369]]
# Observed ΔE: [82.91835317708232, 20.35831039503282, 10.838434426989314, 68.8312316750024]
# Running best ΔE: 10.838434426989314
# Taken 20/96 → X_t.shape=torch.Size([20, 4]), Y_t.shape=torch.Size([20])
# Proposed vols:
# [[ 14.473684 115.789474 101.31579   43.42105 ]
#  [ 57.894737  72.36842   72.36842   72.36842 ]
#  [ 57.894737  14.473684   0.       202.63158 ]
#  [144.73685   28.947369 101.31579    0.      ]]
# Observed ΔE: [88.58919698374237, 64.1621461633886, 80.16304153184385, 10.838434426989314]
# Running best ΔE: 10.838434426989314
# Taken 24/96 → X_t.shape=torch.Size([24, 4]), Y_t.shape=torch.Size([24])
# Proposed vols:
# [[ 28.947369   0.       231.57895   14.473684]
#  [ 43.42105    0.       217.10526   14.473684]
#  [130.26315   14.473684 101.31579   28.947369]
#  [ 57.894737  57.894737 130.26315   28.947369]]
# Observed ΔE: [71.76719014438252, 66.52536886981655, 16.030787369294615, 47.74254005742657]
# Running best ΔE: 10.838434426989314
# Taken 28/96 → X_t.shape=torch.Size([28, 4]), Y_t.shape=torch.Size([28])
# Proposed vols:
# [[ 86.8421    57.894737  57.894737  72.36842 ]
#  [159.21053   14.473684  57.894737  43.42105 ]
#  [ 86.8421    43.42105   28.947369 115.789474]
#  [ 57.894737  72.36842   57.894737  86.8421  ]]
# Observed ΔE: [55.515817439753945, 18.764186876186077, 62.42741096796517, 68.38563834729291]
# Running best ΔE: 10.838434426989314
# Taken 32/96 → X_t.shape=torch.Size([32, 4]), Y_t.shape=torch.Size([32])
# Proposed vols:
# [[ 43.42105   57.894737 130.26315   43.42105 ]
#  [101.31579   43.42105   86.8421    43.42105 ]
#  [ 86.8421    43.42105  144.73685    0.      ]
#  [ 28.947369  28.947369  72.36842  144.73685 ]]
# Observed ΔE: [53.204553007295225, 34.83868321945331, 35.76273048658043, 64.1126761208014]
# Running best ΔE: 10.838434426989314
# Taken 36/96 → X_t.shape=torch.Size([36, 4]), Y_t.shape=torch.Size([36])
# Proposed vols:
# [[144.73685   28.947369 101.31579    0.      ]
#  [  0.       202.63158   43.42105   28.947369]
#  [202.63158    0.         0.        72.36842 ]
#  [246.05263   14.473684   0.        14.473684]]
# Observed ΔE: [10.838434426989314, 140.1571404803538, 35.48609854297217, 36.86977511565407]
# Running best ΔE: 10.838434426989314
# Taken 40/96 → X_t.shape=torch.Size([40, 4]), Y_t.shape=torch.Size([40])
# Proposed vols:
# [[ 86.8421     0.        86.8421   101.31579 ]
#  [246.05263    0.        28.947369   0.      ]
#  [  0.       159.21053   28.947369  86.8421  ]
#  [144.73685   43.42105   86.8421     0.      ]]
# Observed ΔE: [35.68842815771438, 17.270308629073103, 118.24334111148887, 17.309363662393256]
# Running best ΔE: 10.838434426989314
# Taken 44/96 → X_t.shape=torch.Size([44, 4]), Y_t.shape=torch.Size([44])
# Proposed vols:
# [[ 14.473684   0.        72.36842  188.1579  ]
#  [ 43.42105  173.6842    14.473684  43.42105 ]
#  [ 72.36842   72.36842   72.36842   57.894737]
#  [ 43.42105   86.8421   130.26315   14.473684]]
# Observed ΔE: [70.75238315955659, 132.10124791012288, 60.04978940562952, 63.83257897650349]
# Running best ΔE: 10.838434426989314
# Taken 48/96 → X_t.shape=torch.Size([48, 4]), Y_t.shape=torch.Size([48])
# Proposed vols:
# [[144.73685   28.947369 101.31579    0.      ]
#  [  0.        43.42105  217.10526   14.473684]
#  [ 72.36842   28.947369  72.36842  101.31579 ]
#  [115.789474  57.894737 101.31579    0.      ]]
# Observed ΔE: [10.838434426989314, 78.35096823090673, 48.28458593803462, 28.615432492303736]
# Running best ΔE: 10.838434426989314
# Taken 52/96 → X_t.shape=torch.Size([52, 4]), Y_t.shape=torch.Size([52])
